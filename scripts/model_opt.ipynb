# %% [markdown]
# # **Importamos librerias**

# %%
! pip install git+https://github.com/maciejkula/spotlight.git

# !pip install optuna
# Out:
# Collecting git+https://github.com/maciejkula/spotlight.git
#   Cloning https://github.com/maciejkula/spotlight.git to /tmp/pip-req-build-fl2fwkl4
#   Running command git clone --filter=blob:none --quiet https://github.com/maciejkula/spotlight.git /tmp/pip-req-build-fl2fwkl4
#   Resolved https://github.com/maciejkula/spotlight.git to commit 75f4c8c55090771b52b88ef1a00f75bb39f9f2a9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from spotlight==0.1.6) (2.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.0->spotlight==0.1.6) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.0->spotlight==0.1.6) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.0->spotlight==0.1.6) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.0->spotlight==0.1.6) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=0.4.0->spotlight==0.1.6) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=0.4.0->spotlight==0.1.6) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=0.4.0->spotlight==0.1.6) (1.3.0)
# Requirement already satisfied: gdown in /opt/conda/lib/python3.10/site-packages (4.7.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.3.2.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: optuna in /opt/conda/lib/python3.10/site-packages (3.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from optuna) (1.12.0)
# Requirement already satisfied: cmaes>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from optuna) (0.10.0)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.10/site-packages (from optuna) (6.7.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from optuna) (21.3)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from optuna) (2.0.17)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from optuna) (6.0)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (4.6.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/conda/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)

# %%
from google.colab import drive
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import optuna
from spotlight.cross_validation import random_train_test_split
from spotlight.evaluation import precision_recall_score
from spotlight.factorization.implicit import ImplicitFactorizationModel
from spotlight.interactions import Interactions

# %% [markdown]
# # **Extraemos la data**

# %%
# conectamos al drive
drive.mount('/content/drive')

# Definimos el directorio
dir_data_kaggle='./drive/MyDrive/alicorp/data'

# extraemos la data

df_user=pd.read_csv(filepath_or_buffer=dir_data_kaggle+'/df_user.csv')
# Out:
# /opt/conda/lib/python3.10/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1kVpYajCPZva4UAWa90p4Q2JHOx6RzN_-
# From (redirected): https://drive.google.com/uc?id=1kVpYajCPZva4UAWa90p4Q2JHOx6RzN_-&confirm=t&uuid=c9b0391f-7826-482c-a82a-a825cdea1dc8
# To: /kaggle/working/df_user.csv
# 100%|█████████████████████████████████████████| 163M/163M [00:00<00:00, 166MB/s]
# /opt/conda/lib/python3.10/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1-9Bjyvc9vzzcQGJvPS3YoZbhF9EFzPmg
# To: /kaggle/working/df_product.csv
# 100%|██████████████████████████████████████| 31.1k/31.1k [00:00<00:00, 81.0MB/s]

# %% [markdown]
# # **Preliminares sobre la data**

# %%
# definimos el tamaño de la data

len_data=len(df_user)

# definimos las mascaras booleanas

rand_mask=np.random.rand(len_data)

cross_mask=rand_mask<0.8

val_mask=rand_mask>=0.8

# preparamos los arrays

cross_user_array=np.array(df_user['customer_id'][cross_mask])

cross_product_array=np.array(df_user['product_id'][cross_mask])

val_user_array=np.array(df_user['customer_id'][val_mask])

val_product_array=np.array(df_user['product_id'][val_mask])


# interaciones del cross validation
cross_interaction_matrix=Interactions(user_ids=cross_user_array,
                                item_ids=cross_product_array)

# interaciones de la validacion

val_interaction_matrix=Interactions(user_ids=val_user_array,
                                item_ids=val_product_array)

# %% [markdown]
# # **Construimos la funcion objetivo**

# %%
def objective(trial):

    # definimos el rango de las variables

  embedding_dim = trial.suggest_int('embedding_dim', 8,256, step=8)
  n_iter= trial.suggest_int('n_iter',5,100, step=5)
  batch_size=trial.suggest_int('batch_size',32,512, step=32)
  l2=trial.suggest_float('l2',10e-24,10e-8, log=True)
  learning_rate=trial.suggest_float('learning_rate',10e-8,10e-1, log=True)
  num_negative_samples=trial.suggest_int('num_negative_samples',5,50, step=5)


    # picamos las interaciones

  (cross_train,cross_test)=random_train_test_split( interactions=cross_interaction_matrix,
                                        test_percentage=0.2)

    # definimos el modelo

  model=ImplicitFactorizationModel(

                                 loss='adaptive_hinge',
                                 embedding_dim=embedding_dim,
                                 n_iter=n_iter,
                                 batch_size=batch_size,
                                 l2=l2,
                                 learning_rate=learning_rate,
                                 num_negative_samples=num_negative_samples,


                                 use_cuda=True)

    # entrenamos el modelo


  model.fit(interactions=cross_train,verbose=False)

    # evaluamios el modelo

  cross_recall=precision_recall_score(model,cross_test,k=30)[1]

  return cross_recall.mean()

# %% [markdown]
# # **Iniciamos el proceso de busqueda de parametros**

# %%
#Hacemos un estudio

study_alicorp= optuna.create_study(

    study_name='opt_alicorp',
    direction='maximize',
    sampler=optuna.samplers.CmaEsSampler(
        x0=joblib.load(dir_data_kaggle+'/alicorp_params_x0.sav')
                                                )
                                                    )

study_alicorp.optimize(func=objective,
                   n_trials=75,
                   gc_after_trial=True,
                   timeout=43200,
                   show_progress_bar=True)
# Out:
# [I 2023-10-21 04:49:26,321] A new study created in memory with name: opt_alicorp
#   0%|          | 0/75 [00:00<?, ?it/s]
# [I 2023-10-21 04:56:18,730] Trial 0 finished with value: 0.7090775217156632 and parameters: {'embedding_dim': 136, 'n_iter': 35, 'batch_size': 416, 'l2': 1.7185945209483771e-10, 'learning_rate': 5.298852952719548e-05, 'num_negative_samples': 35}. Best is trial 0 with value: 0.7090775217156632.
# [I 2023-10-21 05:01:35,390] Trial 1 finished with value: 0.7185679244448173 and parameters: {'embedding_dim': 120, 'n_iter': 20, 'batch_size': 192, 'l2': 9.706059694479411e-11, 'learning_rate': 0.0020335667317380934, 'num_negative_samples': 15}. Best is trial 1 with value: 0.7185679244448173.
# [I 2023-10-21 05:06:21,846] Trial 2 finished with value: 0.6101113493986847 and parameters: {'embedding_dim': 48, 'n_iter': 20, 'batch_size': 192, 'l2': 1.5413625068704725e-12, 'learning_rate': 9.037203487990745e-06, 'num_negative_samples': 15}. Best is trial 1 with value: 0.7185679244448173.
# [I 2023-10-21 05:13:13,843] Trial 3 finished with value: 0.6638923448442501 and parameters: {'embedding_dim': 24, 'n_iter': 40, 'batch_size': 256, 'l2': 1.9368909420050506e-15, 'learning_rate': 1.995238071217723e-05, 'num_negative_samples': 10}. Best is trial 1 with value: 0.7185679244448173.
# [I 2023-10-21 05:19:55,562] Trial 4 finished with value: 0.7259765718369809 and parameters: {'embedding_dim': 64, 'n_iter': 10, 'batch_size': 64, 'l2': 7.753561772250763e-18, 'learning_rate': 0.0021654091102403, 'num_negative_samples': 10}. Best is trial 4 with value: 0.7259765718369809.
# [I 2023-10-21 05:23:15,946] Trial 5 finished with value: 0.6842470138059809 and parameters: {'embedding_dim': 8, 'n_iter': 10, 'batch_size': 224, 'l2': 4.711551850747027e-13, 'learning_rate': 0.0005170005459379606, 'num_negative_samples': 15}. Best is trial 4 with value: 0.7259765718369809.
# [I 2023-10-21 05:27:46,311] Trial 6 finished with value: 0.70769424024415 and parameters: {'embedding_dim': 8, 'n_iter': 25, 'batch_size': 416, 'l2': 5.75926379025501e-18, 'learning_rate': 0.005432337430070974, 'num_negative_samples': 10}. Best is trial 4 with value: 0.7259765718369809.
# [I 2023-10-21 05:34:36,559] Trial 7 finished with value: 0.6995186714685337 and parameters: {'embedding_dim': 8, 'n_iter': 15, 'batch_size': 96, 'l2': 1.5168632444730072e-15, 'learning_rate': 0.0017565786065411762, 'num_negative_samples': 20}. Best is trial 4 with value: 0.7259765718369809.
# [I 2023-10-21 05:36:08,784] Trial 8 finished with value: 0.6978567880771679 and parameters: {'embedding_dim': 72, 'n_iter': 5, 'batch_size': 256, 'l2': 2.6330221611175794e-17, 'learning_rate': 0.00014671607859071314, 'num_negative_samples': 15}. Best is trial 4 with value: 0.7259765718369809.
# [I 2023-10-21 05:42:38,835] Trial 9 finished with value: 0.4136809219854646 and parameters: {'embedding_dim': 48, 'n_iter': 20, 'batch_size': 224, 'l2': 4.464316665637302e-16, 'learning_rate': 1.3186708982685095e-06, 'num_negative_samples': 15}. Best is trial 4 with value: 0.7259765718369809.
# [I 2023-10-21 06:02:24,774] Trial 10 finished with value: 0.7427965349033461 and parameters: {'embedding_dim': 88, 'n_iter': 30, 'batch_size': 64, 'l2': 3.769570182825942e-17, 'learning_rate': 0.0002785941960021215, 'num_negative_samples': 10}. Best is trial 10 with value: 0.7427965349033461.
# [I 2023-10-21 06:28:27,587] Trial 11 finished with value: 0.6474349906681489 and parameters: {'embedding_dim': 48, 'n_iter': 20, 'batch_size': 32, 'l2': 7.548709673371207e-15, 'learning_rate': 0.00971106470306578, 'num_negative_samples': 5}. Best is trial 10 with value: 0.7427965349033461.
# [I 2023-10-21 06:38:25,586] Trial 12 finished with value: 0.7342277225930754 and parameters: {'embedding_dim': 72, 'n_iter': 15, 'batch_size': 64, 'l2': 1.8308087104688397e-16, 'learning_rate': 7.630455589245181e-05, 'num_negative_samples': 20}. Best is trial 10 with value: 0.7427965349033461.
# [I 2023-10-21 06:51:39,729] Trial 13 finished with value: 0.7362673629397252 and parameters: {'embedding_dim': 96, 'n_iter': 30, 'batch_size': 96, 'l2': 3.298517673056143e-16, 'learning_rate': 0.0005651925860212945, 'num_negative_samples': 10}. Best is trial 10 with value: 0.7427965349033461.
# [I 2023-10-21 06:55:44,138] Trial 14 finished with value: 0.7189342850132185 and parameters: {'embedding_dim': 64, 'n_iter': 20, 'batch_size': 384, 'l2': 1.9487389548894239e-19, 'learning_rate': 0.00013394605082769407, 'num_negative_samples': 25}. Best is trial 10 with value: 0.7427965349033461.
# [I 2023-10-21 06:58:05,584] Trial 15 finished with value: 0.5770371238728748 and parameters: {'embedding_dim': 32, 'n_iter': 10, 'batch_size': 192, 'l2': 1.6143492131971554e-20, 'learning_rate': 2.313150977982092e-05, 'num_negative_samples': 10}. Best is trial 10 with value: 0.7427965349033461.
# [I 2023-10-21 07:09:30,860] Trial 16 finished with value: 0.671027804974042 and parameters: {'embedding_dim': 8, 'n_iter': 30, 'batch_size': 192, 'l2': 5.6571620696650495e-18, 'learning_rate': 0.00038877178250334066, 'num_negative_samples': 25}. Best is trial 10 with value: 0.7427965349033461.
# [I 2023-10-21 07:14:00,930] Trial 17 finished with value: 0.7429307927598282 and parameters: {'embedding_dim': 64, 'n_iter': 10, 'batch_size': 96, 'l2': 3.1243263553835414e-17, 'learning_rate': 0.0007451762902750827, 'num_negative_samples': 5}. Best is trial 17 with value: 0.7429307927598282.
# [I 2023-10-21 07:25:02,769] Trial 18 finished with value: 0.7413912004884758 and parameters: {'embedding_dim': 56, 'n_iter': 25, 'batch_size': 96, 'l2': 2.067834429874433e-08, 'learning_rate': 0.0005189154307728714, 'num_negative_samples': 5}. Best is trial 17 with value: 0.7429307927598282.
# [I 2023-10-21 07:28:01,320] Trial 19 finished with value: 0.7295534376080466 and parameters: {'embedding_dim': 152, 'n_iter': 15, 'batch_size': 224, 'l2': 4.593996511957957e-15, 'learning_rate': 0.0014537233727384376, 'num_negative_samples': 5}. Best is trial 17 with value: 0.7429307927598282.
# [I 2023-10-21 07:36:03,816] Trial 20 finished with value: 0.7275182342142705 and parameters: {'embedding_dim': 40, 'n_iter': 30, 'batch_size': 160, 'l2': 8.89745161177282e-18, 'learning_rate': 0.0022089522846511604, 'num_negative_samples': 10}. Best is trial 17 with value: 0.7429307927598282.
# [I 2023-10-21 07:39:37,359] Trial 21 finished with value: 0.6807793193748333 and parameters: {'embedding_dim': 32, 'n_iter': 15, 'batch_size': 192, 'l2': 4.0461249862766495e-18, 'learning_rate': 5.861246672127926e-05, 'num_negative_samples': 15}. Best is trial 17 with value: 0.7429307927598282.
# [I 2023-10-21 07:44:05,494] Trial 22 finished with value: 0.7479766049727337 and parameters: {'embedding_dim': 80, 'n_iter': 10, 'batch_size': 96, 'l2': 7.821002081809402e-16, 'learning_rate': 0.00037210139196277583, 'num_negative_samples': 5}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 08:03:34,958] Trial 23 finished with value: 0.7244236485609457 and parameters: {'embedding_dim': 56, 'n_iter': 15, 'batch_size': 32, 'l2': 9.68579558959628e-15, 'learning_rate': 0.0014759049129423748, 'num_negative_samples': 5}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 08:27:46,103] Trial 24 finished with value: 0.7131650316816955 and parameters: {'embedding_dim': 88, 'n_iter': 55, 'batch_size': 96, 'l2': 1.120230753507484e-15, 'learning_rate': 0.0022914761117364033, 'num_negative_samples': 10}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 08:29:14,082] Trial 25 finished with value: 0.7414491181258527 and parameters: {'embedding_dim': 64, 'n_iter': 5, 'batch_size': 160, 'l2': 4.376500603703852e-16, 'learning_rate': 0.0007724362499801036, 'num_negative_samples': 5}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 08:30:42,808] Trial 26 finished with value: 0.6242733001247667 and parameters: {'embedding_dim': 104, 'n_iter': 5, 'batch_size': 160, 'l2': 1.4064114287330287e-19, 'learning_rate': 2.6862632175833147e-05, 'num_negative_samples': 10}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 08:56:41,678] Trial 27 finished with value: 0.7228416288915003 and parameters: {'embedding_dim': 16, 'n_iter': 20, 'batch_size': 32, 'l2': 1.6702036894804108e-13, 'learning_rate': 0.0008965091874103406, 'num_negative_samples': 5}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 09:03:22,967] Trial 28 finished with value: 0.6992414689656185 and parameters: {'embedding_dim': 48, 'n_iter': 20, 'batch_size': 128, 'l2': 5.174268527530362e-15, 'learning_rate': 0.005347854141544676, 'num_negative_samples': 10}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 09:05:01,729] Trial 29 finished with value: 0.7393747973850496 and parameters: {'embedding_dim': 40, 'n_iter': 10, 'batch_size': 288, 'l2': 5.352776608108538e-13, 'learning_rate': 0.00037845551150977137, 'num_negative_samples': 10}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 09:21:23,342] Trial 30 finished with value: 0.7408711677630865 and parameters: {'embedding_dim': 48, 'n_iter': 25, 'batch_size': 64, 'l2': 7.461429516587607e-16, 'learning_rate': 0.0005490892214011624, 'num_negative_samples': 10}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 09:37:42,355] Trial 31 finished with value: 0.6263699208567789 and parameters: {'embedding_dim': 40, 'n_iter': 25, 'batch_size': 64, 'l2': 4.435891765642835e-18, 'learning_rate': 0.017139272072474603, 'num_negative_samples': 5}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 09:44:26,562] Trial 32 finished with value: 0.675010205089946 and parameters: {'embedding_dim': 40, 'n_iter': 15, 'batch_size': 96, 'l2': 7.3039546993127e-15, 'learning_rate': 0.00854342398569787, 'num_negative_samples': 15}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 09:57:41,553] Trial 33 finished with value: 0.7233373001554151 and parameters: {'embedding_dim': 128, 'n_iter': 30, 'batch_size': 96, 'l2': 2.984448521148069e-17, 'learning_rate': 0.001226969276943705, 'num_negative_samples': 10}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 10:00:00,952] Trial 34 finished with value: 0.7381474949827057 and parameters: {'embedding_dim': 40, 'n_iter': 10, 'batch_size': 192, 'l2': 1.2395239251177878e-12, 'learning_rate': 0.0010107008560089146, 'num_negative_samples': 5}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 10:02:28,072] Trial 35 finished with value: 0.74318586440067 and parameters: {'embedding_dim': 184, 'n_iter': 5, 'batch_size': 96, 'l2': 1.4714368554870143e-13, 'learning_rate': 0.0006033688035210412, 'num_negative_samples': 15}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 10:03:42,525] Trial 36 finished with value: 0.6801211557957383 and parameters: {'embedding_dim': 72, 'n_iter': 5, 'batch_size': 192, 'l2': 6.964802800360687e-13, 'learning_rate': 0.00011789884513692896, 'num_negative_samples': 5}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 10:07:56,423] Trial 37 finished with value: 0.7150037706373258 and parameters: {'embedding_dim': 80, 'n_iter': 15, 'batch_size': 160, 'l2': 3.004345005555896e-14, 'learning_rate': 0.003152663620658704, 'num_negative_samples': 15}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 10:16:56,028] Trial 38 finished with value: 0.7261042086432657 and parameters: {'embedding_dim': 112, 'n_iter': 45, 'batch_size': 224, 'l2': 1.909669280789895e-10, 'learning_rate': 0.0012107180610243862, 'num_negative_samples': 10}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 10:26:00,193] Trial 39 finished with value: 0.7409096789268399 and parameters: {'embedding_dim': 160, 'n_iter': 20, 'batch_size': 160, 'l2': 1.414890731805614e-14, 'learning_rate': 6.75416076297764e-05, 'num_negative_samples': 20}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 10:34:22,868] Trial 40 finished with value: 0.7471849887113817 and parameters: {'embedding_dim': 160, 'n_iter': 25, 'batch_size': 128, 'l2': 2.524569863937967e-12, 'learning_rate': 0.00016567343154280903, 'num_negative_samples': 10}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 10:39:51,339] Trial 41 finished with value: 0.6753021924162034 and parameters: {'embedding_dim': 88, 'n_iter': 20, 'batch_size': 160, 'l2': 3.0274988497605558e-12, 'learning_rate': 1.8009964909505612e-05, 'num_negative_samples': 10}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 11:06:12,185] Trial 42 finished with value: 0.7373237564535239 and parameters: {'embedding_dim': 168, 'n_iter': 20, 'batch_size': 32, 'l2': 2.9516349127275506e-11, 'learning_rate': 0.00029809487327359997, 'num_negative_samples': 15}. Best is trial 22 with value: 0.7479766049727337.
# [I 2023-10-21 11:09:38,153] Trial 43 finished with value: 0.752738937972121 and parameters: {'embedding_dim': 144, 'n_iter': 10, 'batch_size': 128, 'l2': 3.6782894638223925e-14, 'learning_rate': 0.00019739783297380233, 'num_negative_samples': 10}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 11:13:25,255] Trial 44 finished with value: 0.6681313811759251 and parameters: {'embedding_dim': 104, 'n_iter': 10, 'batch_size': 128, 'l2': 3.3906139406386356e-13, 'learning_rate': 0.006623460449238059, 'num_negative_samples': 20}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 11:18:11,655] Trial 45 finished with value: 0.7428322841400246 and parameters: {'embedding_dim': 168, 'n_iter': 15, 'batch_size': 160, 'l2': 1.0655800765395777e-11, 'learning_rate': 0.00024140458032672474, 'num_negative_samples': 15}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 11:31:47,686] Trial 46 finished with value: 0.7288139021218878 and parameters: {'embedding_dim': 152, 'n_iter': 30, 'batch_size': 160, 'l2': 1.6818416526441588e-11, 'learning_rate': 5.7608831127358235e-05, 'num_negative_samples': 25}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 11:37:33,786] Trial 47 finished with value: 0.7393632512894892 and parameters: {'embedding_dim': 192, 'n_iter': 15, 'batch_size': 128, 'l2': 1.456445341835989e-14, 'learning_rate': 0.0002826854316614279, 'num_negative_samples': 15}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 11:51:56,171] Trial 48 finished with value: 0.7394355238564104 and parameters: {'embedding_dim': 232, 'n_iter': 30, 'batch_size': 160, 'l2': 2.9133375253628915e-12, 'learning_rate': 5.995295381438504e-05, 'num_negative_samples': 20}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 11:56:21,415] Trial 49 finished with value: 0.7399143222165033 and parameters: {'embedding_dim': 216, 'n_iter': 10, 'batch_size': 128, 'l2': 8.936937413982931e-14, 'learning_rate': 0.0002131728877680293, 'num_negative_samples': 20}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 11:58:09,219] Trial 50 finished with value: 0.7375921778598691 and parameters: {'embedding_dim': 128, 'n_iter': 10, 'batch_size': 256, 'l2': 1.870902834057057e-13, 'learning_rate': 0.0012761817965962416, 'num_negative_samples': 5}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 12:00:29,083] Trial 51 finished with value: 0.7472241276333691 and parameters: {'embedding_dim': 152, 'n_iter': 5, 'batch_size': 96, 'l2': 1.3521704278437467e-13, 'learning_rate': 0.00024117795581704929, 'num_negative_samples': 10}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 12:10:26,074] Trial 52 finished with value: 0.7125788161976302 and parameters: {'embedding_dim': 232, 'n_iter': 20, 'batch_size': 96, 'l2': 1.081807015584916e-14, 'learning_rate': 2.4608613656101905e-05, 'num_negative_samples': 5}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 12:13:19,323] Trial 53 finished with value: 0.720033373853398 and parameters: {'embedding_dim': 120, 'n_iter': 15, 'batch_size': 256, 'l2': 1.647190614335449e-10, 'learning_rate': 0.0024635978423425374, 'num_negative_samples': 10}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 12:22:18,848] Trial 54 finished with value: 0.7335081256650592 and parameters: {'embedding_dim': 112, 'n_iter': 35, 'batch_size': 192, 'l2': 3.938732676431412e-16, 'learning_rate': 0.0004282064805642682, 'num_negative_samples': 15}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 12:31:04,591] Trial 55 finished with value: 0.7341138483862248 and parameters: {'embedding_dim': 216, 'n_iter': 15, 'batch_size': 128, 'l2': 1.7260226732031666e-11, 'learning_rate': 6.073761334094936e-05, 'num_negative_samples': 25}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 12:35:58,178] Trial 56 finished with value: 0.7449573210902721 and parameters: {'embedding_dim': 184, 'n_iter': 15, 'batch_size': 160, 'l2': 2.5298892138716417e-12, 'learning_rate': 0.00022578281128528922, 'num_negative_samples': 15}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 12:40:35,015] Trial 57 finished with value: 0.740224585374591 and parameters: {'embedding_dim': 176, 'n_iter': 10, 'batch_size': 160, 'l2': 1.0927198537417692e-08, 'learning_rate': 0.00025720642901644515, 'num_negative_samples': 20}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 12:42:43,308] Trial 58 finished with value: 0.7146329244765506 and parameters: {'embedding_dim': 80, 'n_iter': 15, 'batch_size': 320, 'l2': 1.1494447818007779e-13, 'learning_rate': 9.496156150442344e-05, 'num_negative_samples': 5}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 12:46:37,596] Trial 59 finished with value: 0.6512214896779549 and parameters: {'embedding_dim': 160, 'n_iter': 15, 'batch_size': 288, 'l2': 1.280503859590945e-10, 'learning_rate': 1.1325479899607884e-05, 'num_negative_samples': 15}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 12:48:04,989] Trial 60 finished with value: 0.7304351916286419 and parameters: {'embedding_dim': 152, 'n_iter': 5, 'batch_size': 160, 'l2': 4.2519683117409914e-15, 'learning_rate': 0.00023424646968527398, 'num_negative_samples': 5}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 12:51:20,799] Trial 61 finished with value: 0.7279793778397733 and parameters: {'embedding_dim': 240, 'n_iter': 10, 'batch_size': 192, 'l2': 1.8819900228187756e-13, 'learning_rate': 0.0010876532795600648, 'num_negative_samples': 15}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 12:58:55,889] Trial 62 finished with value: 0.6760307602102557 and parameters: {'embedding_dim': 240, 'n_iter': 10, 'batch_size': 64, 'l2': 1.935628282272063e-10, 'learning_rate': 1.1924586636168489e-05, 'num_negative_samples': 15}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 13:09:27,166] Trial 63 finished with value: 0.74498605192121 and parameters: {'embedding_dim': 208, 'n_iter': 20, 'batch_size': 96, 'l2': 7.353682814788194e-13, 'learning_rate': 5.150274808945938e-05, 'num_negative_samples': 20}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 13:17:36,902] Trial 64 finished with value: 0.6718141884691639 and parameters: {'embedding_dim': 240, 'n_iter': 10, 'batch_size': 64, 'l2': 4.0287620686607685e-11, 'learning_rate': 0.003759808784963456, 'num_negative_samples': 25}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 13:25:24,263] Trial 65 finished with value: 0.7384557902037788 and parameters: {'embedding_dim': 48, 'n_iter': 40, 'batch_size': 224, 'l2': 2.4800538497845016e-12, 'learning_rate': 0.00045239959117240696, 'num_negative_samples': 10}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 13:29:25,867] Trial 66 finished with value: 0.7278263252602484 and parameters: {'embedding_dim': 200, 'n_iter': 5, 'batch_size': 64, 'l2': 1.3033923485637227e-12, 'learning_rate': 0.0003598155204737089, 'num_negative_samples': 30}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 13:36:08,861] Trial 67 finished with value: 0.7403428528610582 and parameters: {'embedding_dim': 160, 'n_iter': 20, 'batch_size': 128, 'l2': 1.3604476142558369e-11, 'learning_rate': 4.195104648778115e-05, 'num_negative_samples': 10}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 13:53:20,888] Trial 68 finished with value: 0.7334845413013656 and parameters: {'embedding_dim': 192, 'n_iter': 25, 'batch_size': 64, 'l2': 4.703035439861727e-16, 'learning_rate': 0.0003077102624733336, 'num_negative_samples': 15}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 14:09:52,739] Trial 69 finished with value: 0.6141501200616996 and parameters: {'embedding_dim': 112, 'n_iter': 25, 'batch_size': 64, 'l2': 1.2864570994294563e-13, 'learning_rate': 2.900832477666805e-06, 'num_negative_samples': 10}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 14:22:02,023] Trial 70 finished with value: 0.7304490921413467 and parameters: {'embedding_dim': 224, 'n_iter': 30, 'batch_size': 128, 'l2': 5.464195263206264e-09, 'learning_rate': 0.000422286443817928, 'num_negative_samples': 15}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 14:36:54,915] Trial 71 finished with value: 0.7342718375203526 and parameters: {'embedding_dim': 200, 'n_iter': 20, 'batch_size': 64, 'l2': 1.0329481062330025e-10, 'learning_rate': 2.1839187670307577e-05, 'num_negative_samples': 25}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 14:42:36,324] Trial 72 finished with value: 0.7143391996272365 and parameters: {'embedding_dim': 160, 'n_iter': 15, 'batch_size': 192, 'l2': 1.4876028619002878e-11, 'learning_rate': 2.881831292551164e-05, 'num_negative_samples': 20}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 14:51:20,265] Trial 73 finished with value: 0.7445766202137734 and parameters: {'embedding_dim': 72, 'n_iter': 45, 'batch_size': 224, 'l2': 2.8389033166612845e-13, 'learning_rate': 0.00020219238579631811, 'num_negative_samples': 10}. Best is trial 43 with value: 0.752738937972121.
# [I 2023-10-21 14:55:28,627] Trial 74 finished with value: 0.6649897673901644 and parameters: {'embedding_dim': 152, 'n_iter': 15, 'batch_size': 160, 'l2': 1.5068549877111335e-08, 'learning_rate': 1.5339781540977378e-05, 'num_negative_samples': 10}. Best is trial 43 with value: 0.752738937972121.

# %% [markdown]
# # **Entrenamos y Evaluamos el modelo**

# %%
print(study_alicorp.best_trial.value)
print(study_alicorp.best_params)
# Out:
# 0.752738937972121
# {'embedding_dim': 144, 'n_iter': 10, 'batch_size': 128, 'l2': 3.6782894638223925e-14, 'learning_rate': 0.00019739783297380233, 'num_negative_samples': 10}

# %%
 # definimos el modelo

model=ImplicitFactorizationModel(

                                 loss='adaptive_hinge',
                                 embedding_dim=study_alicorp.best_params['embedding_dim'],
                                 n_iter=study_alicorp.best_params['n_iter'],
                                 batch_size=study_alicorp.best_params['batch_size'],
                                 l2=study_alicorp.best_params['l2'],
                                 learning_rate=study_alicorp.best_params['learning_rate'],
                                 num_negative_samples=study_alicorp.best_params['num_negative_samples'],
                                 use_cuda=True)


    # Entrenamos el modelo

model.fit(interactions=val_interaction_matrix,verbose=True)
# Out:
# Epoch 0: loss 0.919125403704352
# Epoch 1: loss 0.7428832556266425
# Epoch 2: loss 0.6817310158395247
# Epoch 3: loss 0.6488860024748808
# Epoch 4: loss 0.6225375763150787
# Epoch 5: loss 0.5989675943779009
# Epoch 6: loss 0.5780077375785971
# Epoch 7: loss 0.5593672758553646
# Epoch 8: loss 0.5406348689286959
# Epoch 9: loss 0.5232980774897465

# %%
# evaluamos

val_recall=precision_recall_score(model,val_interaction_matrix,k=30)[1]
print(f'val_recall={np.round(val_recall.mean(),4)}')
# Out:
# val_recall=0.7919

# %%
# nos llevamos los parametros de interes

params=study_alicorp.best_params

joblib.dump(params,dir_data_kaggle+'/alicorp_params_x1.sav')
