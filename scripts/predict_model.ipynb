# %% [markdown]
# # **Instalamos librerias**

# %%
! pip install git+https://github.com/maciejkula/spotlight.git
# Out:
# ...
#   Cloning https://github.com/maciejkula/spotlight.git to /tmp/pip-req-build-89x6wgwm
#   Running command git clone --filter=blob:none --quiet https://github.com/maciejkula/spotlight.git /tmp/pip-req-build-89x6wgwm
#   Resolved https://github.com/maciejkula/spotlight.git to commit 75f4c8c55090771b52b88ef1a00f75bb39f9f2a9
#   Preparing metadata (setup.py) ... done
# ...

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import drive
import joblib
import torch
from spotlight.cross_validation import random_train_test_split
from spotlight.cross_validation import user_based_train_test_split
from spotlight.evaluation import precision_recall_score
from spotlight.factorization.implicit import ImplicitFactorizationModel
from spotlight.interactions import Interactions

# %% [markdown]
# # **Extraemos la data y el modelo**

# %%
# conectamos al drive
drive.mount('/content/drive')

# Definimos el directorio
dir_data_kaggle='./drive/MyDrive/alicorp/data'

# extraemos la data

df_user=pd.read_csv(filepath_or_buffer=dir_data_kaggle+'/df_user.csv')

model = torch.load(dir_data_kaggle+'/model.sav')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Hacemos algunas predicciones**

# %%
unique_product_id=np.array(df_user['product_id'].unique())

user_id=df_user['customer_id'][18]

predict=model.predict(user_ids=user_id,
                      item_ids=unique_product_id)


recommended_product_ids=unique_product_id[np.flip(np.argsort(predict))][:30]

print(recommended_product_ids)
# Out:
# [ 510  452  505  445   11  587  496  439  507  891  890  987  190  120
#  1035  414  404  433  965  926  506  915  426  664  522   76  977  456
#   512   21]
